# %%
print("Hello")
# Out:
# Hello

# %%
import numpy as np
import matplotlib.pyplot as plt

# %%
a = np.arange(0, 10, 0.1)
b = np.sin(a)
plt.plot(a, b)
plt.title("Sine Wave")
plt.xlabel("Angle (radians)")
plt.ylabel("Sine Value")
plt.grid(True)
plt.show()
